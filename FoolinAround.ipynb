# %%
# Just foolin' around

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = './Data/synop_hourly_clean(some nans).csv'

file = pd.read_csv(filename)

# %%
print(file.shape)
file.head(20)
# Out:
# (5447329, 12)
#                            to  stationId  max_temp_w_date  \
# 0   2011-01-01T00:00:00+00:00       6019              4.5
# 1   2011-01-01T00:00:00+00:00       6031              4.2
# 2   2011-01-01T00:00:00+00:00       6032              4.0
# 3   2011-01-01T00:00:00+00:00       6041              4.8
# 4   2011-01-01T00:00:00+00:00       6049              4.0
# 5   2011-01-01T00:00:00+00:00       6051              4.4
# 6   2011-01-01T00:00:00+00:00       6052              4.7
# 7   2011-01-01T00:00:00+00:00       6056              5.1
# 8   2011-01-01T00:00:00+00:00       6058              4.6
# 9   2011-01-01T00:00:00+00:00       6065              4.6
# 10  2011-01-01T00:00:00+00:00       6068              4.6
# 11  2011-01-01T00:00:00+00:00       6070              4.7
# 12  2011-01-01T00:00:00+00:00       6072              4.6
# 13  2011-01-01T00:00:00+00:00       6073              3.4
# 14  2011-01-01T00:00:00+00:00       6074              4.5
# ...

# %%
# for i in file['stationId'].unique():
#     data = file.loc[file['stationId'] == i]
#     # data = data.tail(1000)
#     pressure = data['mean_temp']
#     pressure = np.array(pressure)
#     print(i, len(pressure[np.isnan(pressure)]))
#     # pressure[np.isnan(pressure)] = 0
# Out:
# <class 'range'>

# %%
data = file.loc[file['stationId'] == 6116]
print(data.shape)
data.head(24)
# Out:
# (99594, 12)
#                              to  stationId  max_temp_w_date  \
# 25    2011-01-01T00:00:00+00:00       6116              3.1
# 80    2011-01-01T01:00:00+00:00       6116              3.0
# 135   2011-01-01T02:00:00+00:00       6116              2.9
# 190   2011-01-01T03:00:00+00:00       6116              3.0
# 245   2011-01-01T04:00:00+00:00       6116              2.8
# 300   2011-01-01T05:00:00+00:00       6116              2.9
# 355   2011-01-01T06:00:00+00:00       6116              2.5
# 410   2011-01-01T07:00:00+00:00       6116              2.5
# 465   2011-01-01T08:00:00+00:00       6116              2.6
# 520   2011-01-01T09:00:00+00:00       6116              2.7
# 575   2011-01-01T10:00:00+00:00       6116              2.9
# 630   2011-01-01T11:00:00+00:00       6116              3.1
# 685   2011-01-01T12:00:00+00:00       6116              3.0
# 740   2011-01-01T13:00:00+00:00       6116              2.9
# ...

# %%
# (file['stationId'].unique())

# %%
plt.figure()
plt.plot(np.arange(1000), pressure)
# plt.ylim([1005, 1017.5])
plt.show()
